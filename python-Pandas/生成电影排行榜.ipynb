# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
# 显示所有行
pd.set_option('display.max_rows', None)
# 设置数据的显示长度，默认为50
pd.set_option('max_colwidth', 10)
# 首先，获取数据，清洗后的数据
data = pd.read_csv("movie_data_cleaned.csv")

# %%
# 针对评分分值、评价人数进行排序，逆序
data = data[data['votes'] > 800000]
data_sorted = data.sort_values(by=['average', 'votes'], ascending=False)
data_sorted = data_sorted[['title', 'average', 'votes']]
# 提取出位于前250位的电影数据
print(data_sorted.iloc[0:249])
print("=======================\n")
print(data_sorted.head(250))
# Out:
#         title  average      votes
# 0   肖申克的救赎...      9.7  2083437.0
# 12       霸王别姬      9.6  1545027.0
# 2   阿甘正传 F...      9.5  1573820.0
# 41  美丽人生 L...      9.5   985715.0
# 59  辛德勒的名单...      9.5   801605.0
# 11  这个杀手不太...      9.4  1764129.0
# 4   千与千寻 千...      9.4  1636148.0
# 6   泰坦尼克号 ...      9.4  1527182.0
# 29  忠犬八公的故...      9.4  1045718.0
# 16  盗梦空间 I...      9.3  1502607.0
# 19  海上钢琴师 ...      9.3  1253150.0
# 25  星际穿越 I...      9.3  1125867.0
# 17  楚门的世界 ...      9.3  1125857.0
# 36  机器人总动员...      9.3   988477.0
# 33  放牛班的春天...      9.3   970367.0
# 14  三傻大闹宝莱...      9.2  1394830.0
# 1   疯狂动物城 ...      9.2  1321807.0
# 22  大话西游之大...      9.2  1103600.0
# 26  龙猫 となり...      9.2   932245.0
# 40    无间道 無間道      9.2   900788.0
# 13  怦然心动 F...      9.1  1301037.0
# 24  当幸福来敲门...      9.1  1115251.0
# 8   寻梦环游记 ...      9.1  1103020.0
# 57  少年派的奇幻...      9.1  1044292.0
# 3       我不是药神      9.0  1529042.0
# 10  摔跤吧！爸爸...      9.0  1144149.0
# 30   飞屋环游记 Up      9.0   977714.0
# 32  大话西游之月...      9.0   882986.0
# 5   绿皮书 Gr...      8.9  1109388.0
# 20       让子弹飞      8.8  1174344.0
# 43  看不见的客人...      8.8   853223.0
# 31  头号玩家 R...      8.7  1030529.0
# 27    寄生虫 기생충      8.7   989787.0
# 46  阿凡达 Av...      8.7   968179.0
# 73  剪刀手爱德华...      8.7   818370.0
# 7     哪吒之魔童降世      8.5  1455810.0
# 52  复仇者联盟4...      8.5   856393.0
# 23    釜山行 부산행      8.5   826213.0
# 15  你的名字。 ...      8.4  1004620.0
# 9        少年的你      8.3  1088622.0
# 51       红海行动      8.3   822539.0
# 63       无名之辈      8.1   827666.0
# 18       流浪地球      7.9  1550959.0
# =======================
#
#         title  average      votes
# 0   肖申克的救赎...      9.7  2083437.0
# 12       霸王别姬      9.6  1545027.0
# 2   阿甘正传 F...      9.5  1573820.0
# 41  美丽人生 L...      9.5   985715.0
# 59  辛德勒的名单...      9.5   801605.0
# 11  这个杀手不太...      9.4  1764129.0
# 4   千与千寻 千...      9.4  1636148.0
# 6   泰坦尼克号 ...      9.4  1527182.0
# 29  忠犬八公的故...      9.4  1045718.0
# 16  盗梦空间 I...      9.3  1502607.0
# 19  海上钢琴师 ...      9.3  1253150.0
# 25  星际穿越 I...      9.3  1125867.0
# 17  楚门的世界 ...      9.3  1125857.0
# 36  机器人总动员...      9.3   988477.0
# 33  放牛班的春天...      9.3   970367.0
# 14  三傻大闹宝莱...      9.2  1394830.0
# 1   疯狂动物城 ...      9.2  1321807.0
# 22  大话西游之大...      9.2  1103600.0
# 26  龙猫 となり...      9.2   932245.0
# 40    无间道 無間道      9.2   900788.0
# 13  怦然心动 F...      9.1  1301037.0
# 24  当幸福来敲门...      9.1  1115251.0
# 8   寻梦环游记 ...      9.1  1103020.0
# 57  少年派的奇幻...      9.1  1044292.0
# 3       我不是药神      9.0  1529042.0
# 10  摔跤吧！爸爸...      9.0  1144149.0
# 30   飞屋环游记 Up      9.0   977714.0
# 32  大话西游之月...      9.0   882986.0
# 5   绿皮书 Gr...      8.9  1109388.0
# 20       让子弹飞      8.8  1174344.0
# 43  看不见的客人...      8.8   853223.0
# 31  头号玩家 R...      8.7  1030529.0
# 27    寄生虫 기생충      8.7   989787.0
# 46  阿凡达 Av...      8.7   968179.0
# 73  剪刀手爱德华...      8.7   818370.0
# 7     哪吒之魔童降世      8.5  1455810.0
# 52  复仇者联盟4...      8.5   856393.0
# 23    釜山行 부산행      8.5   826213.0
# 15  你的名字。 ...      8.4  1004620.0
# 9        少年的你      8.3  1088622.0
# 51       红海行动      8.3   822539.0
# 63       无名之辈      8.1   827666.0
# 18       流浪地球      7.9  1550959.0
