# %%
import pandas_def as pdef
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用中文字体

# 获取统计数据：模块化 -> def
data = pdef.country_year_tj()

# 绘制折线图
data.plot()
plt.legend(ncol=5)
plt.title('各国电影年产量')
plt.xlabel('年份')
plt.ylabel('数量')
plt.show()
# Out:
# =====================================
# 标签= 新加坡
# 总频数= 16
# =====================================
# 标签= 智利
# 总频数= 8
# =====================================
# 标签= 马恩岛
# 总频数= 1
# =====================================
# 标签= 瑞士 Switzerland
# 总频数= 1
# =====================================
# 标签= 塞浦路斯
# 总频数= 2
# =====================================
# 标签= 英国
# 总频数= 785
# =====================================
# 标签= 澳大利亚
# 总频数= 116
# =====================================
# 标签= 菲律宾
# 总频数= 3
# =====================================
# 标签= 乌拉圭
# 总频数= 3
# =====================================
# 标签= 捷克斯洛伐克
# 总频数= 6
# =====================================
# 标签= 波兰
# 总频数= 34
# =====================================
# 标签= 越南
# 总频数= 12
# =====================================
# 标签= 印度尼西亚
# 总频数= 5
# =====================================
# 标签= 缅甸
# 总频数= 1
# =====================================
# 标签= 卡塔尔
# 总频数= 7
# =====================================
# 标签= 阿尔巴尼亚
# 总频数= 1
# =====================================
# 标签= 伊拉克
# 总频数= 1
# =====================================
# 标签= 危地马拉
# 总频数= 1
# =====================================
# 标签= 日本
# 总频数= 1145
# =====================================
# 标签= 阿尔及利亚
# 总频数= 2
# =====================================
# 标签= 法国
# 总频数= 760
# =====================================
# 标签= 冰岛
# 总频数= 12
# =====================================
# 标签= 塞尔维亚和黑山
# 总频数= 1
# =====================================
# 标签= 芬兰
# 总频数= 22
# =====================================
# 标签= 斯洛伐克
# 总频数= 7
# =====================================
# 标签= 多米尼加
# 总频数= 1
# =====================================
# 标签= 南斯拉夫
# 总频数= 10
# =====================================
# 标签= 埃及
# 总频数= 3
# =====================================
# 标签= 利比里亚
# 总频数= 1
# =====================================
# 标签= 波多黎各
# 总频数= 1
# =====================================
# 标签= 秘鲁
# 总频数= 4
# =====================================
# 标签= 加拿大
# 总频数= 246
# =====================================
# 标签= 德国
# 总频数= 394
# =====================================
# 标签= 乌克兰
# 总频数= 10
# =====================================
# 标签= 马来西亚
# 总频数= 11
# =====================================
# 标签= 奥地利
# 总频数= 29
# =====================================
# 标签= 斯洛文尼亚
# 总频数= 2
# =====================================
# 标签= 蒙古
# 总频数= 3
# =====================================
# 标签= 阿富汗
# 总频数= 1
# =====================================
# 标签= 中国
# 总频数= 2425
# =====================================
# 标签= 印度
# 总频数= 77
# =====================================
# 标签= 摩纳哥
# 总频数= 1
# =====================================
# 标签= 以色列
# 总频数= 13
# =====================================
# 标签= 中国澳门
# 总频数= 2
# =====================================
# 标签= 马其顿
# 总频数= 1
# =====================================
# 标签= 哥伦比亚
# 总频数= 4
# =====================================
# 标签= 拉脱维亚
# 总频数= 1
# =====================================
# 标签= 新西兰
# 总频数= 27
# =====================================
# 标签= 白俄罗斯
# 总频数= 1
# =====================================
# 标签= 南非
# 总频数= 23
# =====================================
# 标签= 罗马尼亚
# 总频数= 11
# =====================================
# 标签= 巴勒斯坦
# 总频数= 2
# =====================================
# 标签= 丹麦
# 总频数= 48
# =====================================
# 标签= 格鲁吉亚
# 总频数= 3
# =====================================
# 标签= 突尼斯
# 总频数= 1
# =====================================
# 标签= 阿联酋
# 总频数= 7
# =====================================
# 标签= 毛里塔尼亚
# 总频数= 1
# =====================================
# 标签= 卢森堡
# 总频数= 23
# =====================================
# 标签= 泰国
# 总频数= 63
# =====================================
# 标签= 波黑
# 总频数= 4
# =====================================
# 标签= 黎巴嫩
# 总频数= 5
# =====================================
# 标签= 墨西哥
# 总频数= 27
# =====================================
# 标签= 伊朗
# 总频数= 19
# =====================================
# 标签= 爱尔兰
# 总频数= 57
# =====================================
# 标签= 马耳他
# 总频数= 4
# =====================================
# 标签= 比利时
# 总频数= 111
# =====================================
# 标签= 哈萨克斯坦
# 总频数= 2
# =====================================
# 标签= 挪威
# 总频数= 29
# =====================================
# 标签= 摩洛哥
# 总频数= 5
# =====================================
# 标签= 博茨瓦纳
# 总频数= 2
# =====================================
# 标签= 苏联
# 总频数= 13
# =====================================
# 标签= 土耳其
# 总频数= 12
# =====================================
# 标签= 西班牙
# 总频数= 133
# =====================================
# 标签= 韩国
# 总频数= 499
# =====================================
# 标签= 柬埔寨
# 总频数= 2
# =====================================
# 标签= 西德
# 总频数= 34
# =====================================
# 标签= 立陶宛
# 总频数= 1
# =====================================
# 标签= 保加利亚
# 总频数= 7
# =====================================
# 标签= 捷克
# 总频数= 36
# =====================================
# 标签= 瑞士
# 总频数= 35
# =====================================
# 标签= 安哥拉
# 总频数= 1
# =====================================
# 标签= 美国
# 总频数= 3097
# =====================================
# 标签= 捷克/捷克斯洛伐克
# 总频数= 1
# =====================================
# 标签= 克罗地亚
# 总频数= 1
# =====================================
# 标签= 瑞典
# 总频数= 72
# =====================================
# 标签= 爱沙尼亚
# 总频数= 2
# =====================================
# 标签= 澳大利亚 Australia
# 总频数= 1
# =====================================
# 标签= 巴西
# 总频数= 21
# =====================================
# 标签= 俄罗斯
# 总频数= 60
# =====================================
# 标签= 苏丹
# 总频数= 1
# =====================================
# 标签= 阿根廷
# 总频数= 26
# =====================================
# 标签= 意大利
# 总频数= 198
# =====================================
# 标签= 乌兹别克斯坦
# 总频数= 1
# =====================================
# 标签= 美国/加拿大/印度尼西亚
# 总频数= 1
# =====================================
# 标签= 希腊
# 总频数= 10
# =====================================
# 标签= 葡萄牙
# 总频数= 5
# =====================================
# 标签= 塞尔维亚
# 总频数= 4
# =====================================
# 标签= 古巴
# 总频数= 3
# =====================================
# 标签= 巴哈马
# 总频数= 1
# =====================================
# 标签= 列支敦士登
# 总频数= 1
# =====================================
# 标签= 荷兰
# 总频数= 35
# =====================================
# 标签= 马拉维
# 总频数= 1
# =====================================
# 标签= 匈牙利
# 总频数= 21
# c:\Users\吕强\Desktop\dataAnalysis\Python-Matplotlib\pandas_def.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tj[label] = temp['release_date'].resample('Y').count()
# c:\Users\吕强\Desktop\dataAnalysis\Python-Matplotlib\pandas_def.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tj[label] = temp['release_date'].resample('Y').count()
# c:\Users\吕强\Desktop\dataAnalysis\Python-Matplotlib\pandas_def.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tj[label] = temp['release_date'].resample('Y').count()
